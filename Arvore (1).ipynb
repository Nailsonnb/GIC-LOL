# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
# %matplotlib inline
import itertools
import matplotlib.pyplot as plt

def Print_MC(cm):
    
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Dark2)
    plt.title('Matriz de confusão')
    plt.colorbar()
    tick_marks = np.arange(2)
    plt.xticks(tick_marks)
    plt.yticks(tick_marks)
    fmt = '.0f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('Valor real')
    plt.xlabel('Valor previsto')
    cnf_matrix = confusion_matrix(y_test, y_predict)
    np.set_printoptions(precision=2)
    plt.figure()
    plt.show

# %%
df = pd.read_csv(r'D:\Nailson\5 periodo\GIC\league of References\agora vai\21-11\WinRateNN4.csv')
X = df.drop('bResult', axis=1)
y = df['bResult']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
#print(y_predict)
print(accuracy_score(y_test, y_predict))
cm = confusion_matrix(y_predict, y_test)

Print_MC(cm)
# Out:
# 0.516213847502

# %%
df = pd.read_csv(r'D:\Nailson\5 periodo\GIC\league of References\agora vai\21-11\WinRateMaiorDeDez.csv')
X = df.drop('bResult', axis=1)
y = df['bResult']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
#print(y_predict)
print(accuracy_score(y_test, y_predict))
cm = confusion_matrix(y_predict, y_test)

Print_MC(cm)
# Out:
# 0.526315789474

# %%
df = pd.read_csv(r'D:\Nailson\5 periodo\GIC\league of References\agora vai\21-11\WinRateMaiorDeDezComOuro5.csv', sep=';')
X = df.drop('bResult', axis=1)
y = df['bResult']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
#print(y_predict)
print(accuracy_score(y_test, y_predict))
cm = confusion_matrix(y_predict, y_test)

Print_MC(cm)
# Out:
# 0.548617305977

# %%
df = pd.read_csv(r'D:\Nailson\5 periodo\GIC\league of References\agora vai\21-11\WinRateMaiorDeDezMediaEOuro.csv', sep=';')
X = df.drop('bResult', axis=1)
y = df['bResult']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)
model = tree.DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
#print(y_predict)
print(accuracy_score(y_test, y_predict))
cm = confusion_matrix(y_predict, y_test)

#dotfile = open("WinRateMaiorDeDezMediaEOuro.dot", 'w')
#tree.export_graphviz(model, out_file=dotfile, feature_names=['bgold','rgold','mblue','mred',],class_names=['0','1'])
#dotfile.close()

Print_MC(cm)
# Out:
# 0.567350579839

# %%
df = pd.read_csv(r'D:\Nailson\5 periodo\GIC\league of References\agora vai\21-11\DiferencaOuro2.csv', sep=',')
X = df.drop('bResult', axis=1)
y = df['bResult']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.5)
model = tree.DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
#print(y_predict)
print(accuracy_score(y_test, y_predict))
cm = confusion_matrix(y_predict, y_test)
Print_MC(cm)

#dotfile = open("DiferencaOuro2-1.dot", 'w')
#tree.export_graphviz(model, out_file=dotfile, feature_names=['t1','t2','t3','t4','t5','t6','t7','t8','t9','t10',],class_names=['0','1'])
#dotfile.close()
# Out:
# 0.970015781168
